# %%
print("헬로우 고준영")
# Out:
# 헬로우 고준영

# %% [markdown]
# # **구글 드라이브에서 파일 불러오기**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls # 현재 위치의 파일 파악하기
print('----')
# !ls -al # 접근 권한, 생성 날자, 숨겨진 파일까지 보여줌
# Out:
# drive  sample_data
# ----
# total 20
# drwxr-xr-x 1 root root 4096 Mar  2 04:00 .
# drwxr-xr-x 1 root root 4096 Mar  2 03:52 ..
# drwxr-xr-x 1 root root 4096 Feb 18 14:33 .config
# drwx------ 5 root root 4096 Mar  2 04:00 drive
# drwxr-xr-x 1 root root 4096 Feb 18 14:33 sample_data

# %%
# !pwd # 현재 위치의 경로 파악하기
# Out:
# /content

# %%
# !ls ./drive/MyDrive -la # 해당 경로의 파일을 봅니다.

# %% [markdown]
# # **이미지 불러오기**

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img = mpimg.imread('./drive/MyDrive/KOH.png')
plt.imshow(img)
