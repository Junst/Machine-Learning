# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

data_loc = 'https://github.com/dknife/ML/raw/main/data/'
df = pd.read_csv(data_loc+'nonlinear.csv')

plt.scatter(df['x'],df['y'])

# %%
from sklearn.preprocessing import PolynomialFeatures

X= df['x'].to_numpy()
y= df['y'].to_numpy()
X=X.reshape(-1,1)
feature_cubic= PolynomialFeatures(degree=3)
X_3= feature_cubic.fit_transform(X)
X_3
# Out:
# array([[1.00000000e+00, 3.47942580e-02, 1.21064039e-03, 4.21233340e-05],
#        [1.00000000e+00, 5.37594581e-02, 2.89007933e-03, 1.55369099e-04],
#        [1.00000000e+00, 4.93225160e-02, 2.43271058e-03, 1.19987407e-04],
#        ...,
#        [1.00000000e+00, 4.14284197e-01, 1.71631396e-01, 7.11041752e-02],
#        [1.00000000e+00, 5.75049972e-01, 3.30682470e-01, 1.90158945e-01],
#        [1.00000000e+00, 4.93889763e-01, 2.43927098e-01, 1.20473097e-01]])

# %%
lin_model = LinearRegression()
domain = np.linspace(0,1,100).reshape(-1,1)
domain
# Out:
# array([[0.        ],
#        [0.01010101],
#        [0.02020202],
#        [0.03030303],
#        [0.04040404],
#        [0.05050505],
#        [0.06060606],
#        [0.07070707],
#        [0.08080808],
#        [0.09090909],
#        [0.1010101 ],
#        [0.11111111],
#        [0.12121212],
#        [0.13131313],
#        [0.14141414],
#        [0.15151515],
#        [0.16161616],
#        [0.17171717],
#        [0.18181818],
#        [0.19191919],
#        [0.2020202 ],
#        [0.21212121],
#        [0.22222222],
#        [0.23232323],
#        [0.24242424],
#        [0.25252525],
#        [0.26262626],
#        [0.27272727],
#        [0.28282828],
#        [0.29292929],
#        [0.3030303 ],
#        [0.31313131],
#        [0.32323232],
#        [0.33333333],
#        [0.34343434],
#        [0.35353535],
#        [0.36363636],
#        [0.37373737],
#        [0.38383838],
#        [0.39393939],
#        [0.4040404 ],
#        [0.41414141],
#        [0.42424242],
# ...

# %%
lin_model.fit(X_3,y)
domain_3=feature_cubic.fit_transform(domain)
predictions=lin_model.predict(domain_3)
plt.scatter(df['x'],df['y'])
plt.scatter(domain,predictions,color='r')

# %% [markdown]
# ## 2번

# %%
print(feature_cubic.get_feature_names())
# Out:
# ['1', 'x0', 'x0^2', 'x0^3']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print('다항 회귀 모델의 점수 =', lin_model.score(X_3,y).round(3))
print('다항 회귀 모델의 계수 =', lin_model.coef_, '절편=',lin_model.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.559
# 다항 회귀 모델의 계수 = [  0.          11.81632505 -33.56653584  22.61173063] 절편= -0.15934653669293156

# %% [markdown]
# ## 4번

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

data_loc = 'https://github.com/dknife/ML/raw/main/data/'
df = pd.read_csv(data_loc+'nonlinear.csv')

plt.scatter(df['x'],df['y'])

# %%
from sklearn.preprocessing import PolynomialFeatures

X= df['x'].to_numpy()
y= df['y'].to_numpy()
X=X.reshape(-1,1)
feature_cubic= PolynomialFeatures(degree=4)
X_4= feature_cubic.fit_transform(X)
X_4
# Out:
# array([[1.00000000e+00, 3.47942580e-02, 1.21064039e-03, 4.21233340e-05,
#         1.46565015e-06],
#        [1.00000000e+00, 5.37594581e-02, 2.89007933e-03, 1.55369099e-04,
#         8.35255856e-06],
#        [1.00000000e+00, 4.93225160e-02, 2.43271058e-03, 1.19987407e-04,
#         5.91808077e-06],
#        ...,
#        [1.00000000e+00, 4.14284197e-01, 1.71631396e-01, 7.11041752e-02,
#         2.94573361e-02],
#        [1.00000000e+00, 5.75049972e-01, 3.30682470e-01, 1.90158945e-01,
#         1.09350896e-01],
#        [1.00000000e+00, 4.93889763e-01, 2.43927098e-01, 1.20473097e-01,
#         5.95004293e-02]])

# %%
lin_model = LinearRegression()
domain4 = np.linspace(0,1,100).reshape(-1,1)
domain4
# Out:
# array([[0.        ],
#        [0.01010101],
#        [0.02020202],
#        [0.03030303],
#        [0.04040404],
#        [0.05050505],
#        [0.06060606],
#        [0.07070707],
#        [0.08080808],
#        [0.09090909],
#        [0.1010101 ],
#        [0.11111111],
#        [0.12121212],
#        [0.13131313],
#        [0.14141414],
#        [0.15151515],
#        [0.16161616],
#        [0.17171717],
#        [0.18181818],
#        [0.19191919],
#        [0.2020202 ],
#        [0.21212121],
#        [0.22222222],
#        [0.23232323],
#        [0.24242424],
#        [0.25252525],
#        [0.26262626],
#        [0.27272727],
#        [0.28282828],
#        [0.29292929],
#        [0.3030303 ],
#        [0.31313131],
#        [0.32323232],
#        [0.33333333],
#        [0.34343434],
#        [0.35353535],
#        [0.36363636],
#        [0.37373737],
#        [0.38383838],
#        [0.39393939],
#        [0.4040404 ],
#        [0.41414141],
#        [0.42424242],
# ...

# %%
lin_model.fit(X_4,y)
domain_4=feature_cubic.fit_transform(domain)
predictions=lin_model.predict(domain_4)
plt.scatter(df['x'],df['y'])
plt.scatter(domain4,predictions,color='r')

# %%
print(feature_cubic.get_feature_names())
# Out:
# ['1', 'x0', 'x0^2', 'x0^3', 'x0^4']
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
print('다항 회귀 모델의 점수 =', lin_model.score(X_4,y).round(4))
print('다항 회귀 모델의 계수 =', lin_model.coef_, '절편=',lin_model.intercept_)
# Out:
# 다항 회귀 모델의 점수 = 0.5595
# 다항 회귀 모델의 계수 = [  0.          11.3591425  -31.48737996  19.35670669   1.63408182] 절편= -0.13703423888266317
